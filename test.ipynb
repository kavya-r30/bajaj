# %%
from grag import GraphRAG
import os
from dotenv import load_dotenv
load_dotenv()

# %%
pdf_directory = "./docs/"
neo4j_uri = "bolt://localhost:7687"
neo4j_username = "neo4j"
neo4j_password = "viraj1234"
google_api_key = os.getenv("GOOGLE_API_KEY")

# Create an instance
grag = GraphRAG(
    pdf_directory=pdf_directory,
    neo4j_uri=neo4j_uri,
    neo4j_username=neo4j_username,
    neo4j_password=neo4j_password,
    google_api_key=google_api_key
)

# Create the chain
chain = grag.create_chain()

# Run a query through the chain
question = "What organizations are mentioned in the documents?"
result = chain.invoke({"question": question})

print("Final Answer:")
print(result)
# Out:
# [INFO] Initializing GraphRAG...
# [INFO] Loading PDF files from directory: ./docs/
# [INFO] Loaded 49 documents from PDF.
# [INFO] Splitting documents into chunks...
# [INFO] Split into 147 text chunks.
# [INFO] Initializing Google Generative AI LLM...
# [INFO] Extracting graph documents using LLMGraphTransformer...
# [INFO] Extracted 49 graph documents.
# ...

# %%
question = "Is treatment for alcoholism covered under the Mental Illness Treatment section of the policy?"
result = chain.invoke({"question": question})

print("Final Answer:")
print(result)
# Out:
# [INFO] Performing hybrid retrieval for question: Is treatment for alcoholism covered under the Mental Illness Treatment section of the policy?
# [INFO] Running structured retriever for question: Is treatment for alcoholism covered under the Mental Illness Treatment section of the policy?
# ...

# %%
question = 'What are the relationships between "Pre-hospitalization" and "In-patient Hospitalization" in terms of coverage?'
result = chain.invoke({"question": question})

print("Final Answer:")
print(result)
# Out:
# [INFO] Performing hybrid retrieval for question: What are the relationships between "Pre-hospitalization" and "In-patient Hospitalization" in terms of coverage?
# [INFO] Running structured retriever for question: What are the relationships between "Pre-hospitalization" and "In-patient Hospitalization" in terms of coverage?
# ...

# %%
question = 'Which conditions must be met for Maternity Expenses to be covered under the policy?'
result = chain.invoke({"question": question})

print("Final Answer:")
print(result)
# Out:
# [INFO] Performing hybrid retrieval for question: Which conditions must be met for Maternity Expenses to be covered under the policy?
# [INFO] Running structured retriever for question: Which conditions must be met for Maternity Expenses to be covered under the policy?
# ...

# %%
question = 'What is the relationship between Air Ambulance and the Imperial Plus Plan?'
result = chain.invoke({"question": question})

print("Final Answer:")
print(result)
# Out:
# [INFO] Performing hybrid retrieval for question: What is the relationship between Air Ambulance and the Imperial Plus Plan?
# [INFO] Running structured retriever for question: What is the relationship between Air Ambulance and the Imperial Plus Plan?
# ...

# %%
question = 'How does Portability relate to pre-existing conditions in the policy?'
result = chain.invoke({"question": question})

print("Final Answer:")
print(result)
# Out:
# [INFO] Performing hybrid retrieval for question: How does Portability relate to pre-existing conditions in the policy?
# [INFO] Running structured retriever for question: How does Portability relate to pre-existing conditions in the policy?
# ...

# %%
question = 'What is the definition of "Cashless Facility" in the Bajaj Allianz Global Health Care Policy?'
result = chain.invoke({"question": question})

print("Final Answer:")
print(result)
# Out:
# [INFO] Performing hybrid retrieval for question: What is the definition of "Cashless Facility" in the Bajaj Allianz Global Health Care Policy?
# [INFO] Running structured retriever for question: What is the definition of "Cashless Facility" in the Bajaj Allianz Global Health Care Policy?
# ...

# %%
question = 'What are "Surgical Appliances and Materials" as per the policy?'
result = chain.invoke({"question": question})

print("Final Answer:")
print(result)
# Out:
# [INFO] Performing hybrid retrieval for question: What are "Surgical Appliances and Materials" as per the policy?
# [INFO] Running structured retriever for question: What are "Surgical Appliances and Materials" as per the policy?
# ...

# %%
question = 'If a policyholder has a pre-existing condition like Chronic Kidney Disease, how long is the waiting period, and how does it change with portability?'
result = chain.invoke({"question": question})

print("Final Answer:")
print(result)
# Out:
# [INFO] Performing hybrid retrieval for question: If a policyholder has a pre-existing condition like Chronic Kidney Disease, how long is the waiting period, and how does it change with portability?
# [INFO] Running structured retriever for question: If a policyholder has a pre-existing condition like Chronic Kidney Disease, how long is the waiting period, and how does it change with portability?
# ...

# %%
question = 'If a policyholder requires emergency hospitalization for a condition not available locally, what options does the policy provide for treatment abroad?'
result = chain.invoke({"question": question})

print("Final Answer:")
print(result)
# Out:
# [INFO] Performing hybrid retrieval for question: If a policyholder requires emergency hospitalization for a condition not available locally, what options does the policy provide for treatment abroad?
# [INFO] Running structured retriever for question: If a policyholder requires emergency hospitalization for a condition not available locally, what options does the policy provide for treatment abroad?
# ...

# %%
question = 'Are non-prescribed creams or lotions covered under medical expenses, according to Annexure II?'
result = chain.invoke({"question": question})

print("Final Answer:")
print(result)
# Out:
# [INFO] Performing hybrid retrieval for question: Are non-prescribed creams or lotions covered under medical expenses, according to Annexure II?
# [INFO] Running structured retriever for question: Are non-prescribed creams or lotions covered under medical expenses, according to Annexure II?
# ...

# %%
question = 'If a policyholder undergoes robotic surgery, is it covered, and what are the applicable terms and conditions?'
result = chain.invoke({"question": question})

print("Final Answer:")
print(result)
# Out:
# [INFO] Performing hybrid retrieval for question: If a policyholder undergoes robotic surgery, is it covered, and what are the applicable terms and conditions?
# [INFO] Running structured retriever for question: If a policyholder undergoes robotic surgery, is it covered, and what are the applicable terms and conditions?
# ...

# %%
question = 'What is the contact number for claims under the Global Health Care Policy?'
result = chain.invoke({"question": question})

print("Final Answer:")
print(result)
# Out:
# [INFO] Performing hybrid retrieval for question: What is the contact number for claims under the Global Health Care Policy?
# [INFO] Running structured retriever for question: What is the contact number for claims under the Global Health Care Policy?
# ...

# %%
question = 'What happens if a policyholder misses the premium payment during the grace period?'
result = chain.invoke({"question": question})

print("Final Answer:")
print(result)
# Out:
# [INFO] Performing hybrid retrieval for question: What happens if a policyholder misses the premium payment during the grace period?
# [INFO] Running structured retriever for question: What happens if a policyholder misses the premium payment during the grace period?
# ...

# %%
question = 'What are the conditions under which obesity treatment is excluded (Code-Excl06)?'
result = chain.invoke({"question": question})

print("Final Answer:")
print(result)
# Out:
# [INFO] Performing hybrid retrieval for question: What are the conditions under which obesity treatment is excluded (Code-Excl06)?
# [INFO] Running structured retriever for question: What are the conditions under which obesity treatment is excluded (Code-Excl06)?
# ...

# %%
question = 'What is the maximum liability for "Local (Road) Ambulance" under the policy?'
result = chain.invoke({"question": question})

print("Final Answer:")
print(result)
# Out:
# [INFO] Performing hybrid retrieval for question: What is the maximum liability for "Local (Road) Ambulance" under the policy?
# [INFO] Running structured retriever for question: What is the maximum liability for "Local (Road) Ambulance" under the policy?
# ...

# %%
question = 'What types of organ transplants are covered under the policy?'
result = chain.invoke({"question": question})

print("Final Answer:")
print(result)
# Out:
# [INFO] Performing hybrid retrieval for question: What types of organ transplants are covered under the policy?
# [INFO] Running structured retriever for question: What types of organ transplants are covered under the policy?
# ...

# %%
question = 'How does the policy handle claims for a procedure like Uterine Artery Embolization if its performed in a non-network hospital?'
result = chain.invoke({"question": question})

print("Final Answer:")
print(result)
# Out:
# [INFO] Performing hybrid retrieval for question: How does the policy handle claims for a procedure like Uterine Artery Embolization if its performed in a non-network hospital?
# [INFO] Running structured retriever for question: How does the policy handle claims for a procedure like Uterine Artery Embolization if its performed in a non-network hospital?
# ...
